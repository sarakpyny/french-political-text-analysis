# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %%
import pandas as pd
import numpy as np

# load cleaned data
df_cleaned = pd.read_csv('../data/processed/data_cleaned.csv', low_memory=False)
df_cleaned.shape
# Out:
# (3596, 13)

# %%
print(df_cleaned.head().to_string())
# Out:
#                                id        date                   titulaire-liste titulaire-profession titulaire-age-calcule titulaire-sexe departement-insee                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# 0  EL134_L_1981_06_001_03_1_PF_02  1981-06-14                Union de la gauche           agent SNCF                    35          homme          01 - Ain                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Sciences Po / fonds CEVIPOF\nRÉPUBLIQUE FRANÇAISE - LIBERTÉ - ÉGALITÉ - FRATERNITÉ - DÉPARTEMENT DE L'AIN\nELECTIONS LÉGISLATIVES - 14 JUIN 1981\n3º circonscription de l'Ain\nFernand ROUSTIT\nCANDIDAT POUR LA MAJORITÉ D'UNION DE LA GAUCHE\nFernand ROUSTIT\n35 ans, marié, père de 2 enfants Agent S.N.C.F. Responsable syndical Délégué auprès de la Direction régionale de la S.N.C.F.\nMarie-Louise LEVRAT Secrétaire de Direction\nSuppléante Marie - Louise LEVRAT\nSecrétaire de Direction\nMADAME, MADEMOISELLE, MONSIEUR,\nEnsemble nous avons gagné, vous et moi nous nous sommes félicités d'avoir battu l'équipe de misère, de chômage, l'équipe au service exclusif des intérêts de la grande bourgeoisie qui dominait le pays depuis 23 ans.\nLe premier pas important a été franchi le 10 mai 1981 avec la défaite de Giscard d'Estaing et l'élection de François MITTERRAND.\nJe m'en réjouis d'autant plus que moi-même, depuis plus de 15 ans, en tant que travailleur, militant syndicaliste, j'ai apporté toute ma contribution à la bataille pour battre Giscard d'Estaing, lutter pour réaliser l'union et ouvrir par mon engagement la porte au changement. Je m'en réjouis avec tous ceux qui y ont contribué par leur vote et au lendemain du 26 avril, avec tous les communistes, j'ai appelé à voter François MITTERRAND.\nAujourd'hui l'objectif est clair. Je vous propose de tout mettre en œuvre pour réussir ensemble le changement, pour répondre à l'attente du pays. C'est-à-dire, ensemble, élire une majorité de gauche à l'Assemblée Nationale, mettre en place un gouvernement dans lequel se retrouveront toutes les forces qui ont contribué à la victoire.\nComme vous, travailleur, père de famille, militant syndicaliste, engagé dans la vie associative, ayant le souci de l'avenir, je veux développer avec ténacité et sérieux l'action pour le plein emploi, la justice sociale, l'amélioration de la vie des familles, des jeunes, la solution des problèmes de l'école, du logement, de la santé, assurer la progression du revenu agricole, l'essor de notre économie grâce à des réformes, le progrès de la démocratie, le rôle indépendant de la France dans le monde au service de la paix, du désarmement, de l'amitié et de la solidarité des peuples.\nIl y aura beaucoup à faire et il y aura besoin de toutes les énergies. ☐Sciences Po / fonds CEVIPOF\nDans cette 3e circonscription de l'Ain, les électrices et les électeurs ont, aux élections partielles de 1980, envoyé siéger à l'Assemblée Nationale un député socialiste. La droite est donc battue, bien battue et nous serons, vous et moi, d'autant plus sûrs que la gauche soit représentée à nouveau que le Parti Communiste ait le nombre de voix nécessaire pour la victoire. Vous avez été en 1978 plus de 8.800 électrices et
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# 4  EL134_L_1981_06_002_02_1_PF_02  1981-06-14  Union pour une nouvelle majorité          vétérinaire                    56          homme        02 - Aisne                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Sciences Po / fonds CEVIPOF\nLucien BOCHARD\nELECTIONS LEGISLATIVES DE JUIN 1981\n2e circonscription de l'Aisne\nA mes amis de l'arrondissement de Saint-Quentin\nVOUS POUVEZ ENCORE CHOISIR ...\n- POUR LA DEFENSE DES VALEURS MORALES ET SPIRITUELLES\n- CONTRE UN PROGRAMME SOCIALO-COMMUNISTE\n- CONTRE l'ETATISATION\n- CONTRE LE CONTROLE COLLECTIF DES ACHATS ET DES VENTES DES TERRES AGRICOLES\n- POUR LA LIBERTE, D'ENTREPRENDRE ET D'ENSEIGNEMENT\n- CONTRE LE DEVELOPPEMENT DE LA MEDECINE « INTEGREE » où le libre choix du médecin n'est plus possible\n- POUR L'EMPLOI ET LA SECURITE DANS LA LIBERTE\n- CONTRE LA NATIONALISATION DE LA MOITIE DE L'INDUSTRIE FRANÇAISE ET DE TOUT LE SECTEUR BANCAIRE ET D'ASSURANCES\nVOTEZ POUR LE CANDIDAT DE l'U.D.F., U.N.M. Il n'y a  ...

# %%
df_cleaned.columns
# Out:
# Index(['id', 'date', 'titulaire-liste', 'titulaire-profession',
#        'titulaire-age-calcule', 'titulaire-sexe', 'departement-insee', 'text',
#        'word_count', 'year', 'profession_clean', 'party_clean', 'text_lemma'],
#       dtype='str')

# %%
# stats of word count of text
df_cleaned['word_count'].describe()
# Out:
# count    3596.000000
# mean      637.065072
# std       289.338109
# min       130.000000
# 25%       464.000000
# 50%       555.000000
# 75%       784.000000
# max      2765.000000
# Name: word_count, dtype: float64

# %%
# party
df_cleaned["party_clean"].value_counts().head(15)
# Out:
# party_clean
# Other                                          864
# Liste d'entente populaire et nationale         450
# Entente des écologistes                        421
# Union pour une nouvelle majorité               350
# Union du rassemblement et du centre            310
# Majorité présidentielle pour la France unie    287
# Rassemblement des forces de gauche             266
# Majorité de la France                          172
# Alliance des Français pour le progrès          155
# Majorité d'union de la gauche                  140
# Union pour la France                           126
# Majorité présidentielle                         55
# Name: count, dtype: int64

# %%
# profession
df_cleaned["profession_clean"].value_counts()
# Out:
# profession_clean
# Other          1454
# Education       617
# Health          303
# Business        300
# Technical       278
# Law             195
# Worker          188
# Agriculture     111
# Political        95
# Media            55
# Name: count, dtype: int64

# %%
# distribution docs length
import matplotlib.pyplot as plt

plt.hist(df_cleaned['word_count'], bins=50)
plt.title("Document Length Distribution")
plt.xlabel("Word Count")
plt.ylabel("Frequency")
plt.show()

# %%
# boxplot of docs length
plt.boxplot(df_cleaned['word_count'], vert=False)
plt.title("Document Length Boxplot")
plt.show()

# %%
# distribution of profession
df_cleaned['profession_clean'].value_counts().plot(kind='bar')
plt.title("Profession Distribution")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### CountVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Initialize CountVectorizer
vectorizer = CountVectorizer()

# Fit and transform
X = vectorizer.fit_transform(df_cleaned['text'])

# Get words and counts
words = vectorizer.get_feature_names_out()
word_counts = np.array(X.sum(axis=0)).flatten()

# Combine and sort
freq = [(word, int(word_counts[i])) for i, word in enumerate(words)]
freq_sorted = sorted(freq, key=lambda x: x[1], reverse=True)

# Top 20
freq_sorted[:20]
# Out:
# [('de', 119942),
#  ('la', 79654),
#  ('et', 66050),
#  ('le', 51351),
#  ('les', 49450),
#  ('des', 42129),
#  ('pour', 38179),
#  ('du', 29732),
#  ('en', 21693),
#  ('une', 20812),
#  ('qui', 18598),
#  ('est', 18266),
#  ('un', 16456),
#  ('que', 14947),
#  ('dans', 14536),
#  ('vous', 13818),
#  ('nous', 13264),
#  ('au', 13133),
#  ('il', 12381),
#  ('par', 11903)]

# %%
# Take top words
top_words = freq_sorted[:20]

words = [w[0] for w in top_words]
counts = [w[1] for w in top_words]

# Plot
plt.figure(figsize=(10,8))
plt.barh(words, counts)
plt.xlabel("Frequency")
plt.title("Top 20 Most Frequent Words in Corpus without Stopwords Removed")
plt.gca().invert_yaxis()
plt.show()

# %%
import nltk

# download stopwords
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/nysarakpy/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# load stopwords
french_stopwords = stopwords.words("french")

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Initialize CountVectorizer
vectorizer = CountVectorizer(
    stop_words=french_stopwords,
    token_pattern=r'\b[a-zA-ZÀ-ÿ]{3,}\b',  # only words longer than 3 letters and no numbers to prevent temporal when modeling
    max_df=0.95,
    min_df=20
)

# Fit and transform
X = vectorizer.fit_transform(df_cleaned['text'])

# Get words and counts
words = vectorizer.get_feature_names_out()
word_counts = np.array(X.sum(axis=0)).flatten()

# Combine and sort
freq = [(word, int(word_counts[i])) for i, word in enumerate(words)]
freq_sorted = sorted(freq, key=lambda x: x[1], reverse=True)

# Take top words
top_words = freq_sorted[:20]
words = [w[0] for w in top_words]
counts = [w[1] for w in top_words]

# Plot
plt.figure(figsize=(10,8))
plt.barh(words, counts)
plt.xlabel("Frequency")
plt.title("Top 20 Most Frequent Words in Corpus with Stopwords Removed")
plt.gca().invert_yaxis() 
plt.show()

# %%
# Additional corpus-specific stopwords
extra_stopwords = {

    # Archive artifacts
    "cevipof","fonds",

    # Election formatting
    "circonscription","elections","législatives","tour",

    # Candidate biography
    "candidat","candidats","suppléant","suppléants",
    "maire","conseiller","ans",

    # Weak rhetorical words
    "comme","contre","faire","fait","faut",
    "ceux","leurs","depuis","tout","tous",
    "être","falloir","vouloir","mettre","donner",

    # OCR artifacts (German)
    "die","der","und","für","den","sie","eine","das",
    "wir","werden","auf","nicht","einer","dass","gegen",
    "ihr","auch","mit","von","ist","dem","ein","ich",
    "sich","wird","haben","durch","ihre","als",
    "frankreich","leben","sind","mehr","einen","politik",
    "mehrheit","hat","geben","juni","werden","nicht",

    # Geographic artifacts
    "alsace","strasbourg",

    # Formatting tokens
    "mai","juin","mars",
    "monsieur","madame","mademoiselle",
}

# Standard French stopwords
french_stopwords = set(stopwords.words('french'))

# Combine stopwords
all_stopwords = list(french_stopwords.union(extra_stopwords))

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Initialize CountVectorizer
vectorizer = CountVectorizer(
    stop_words=all_stopwords,
    token_pattern=r'\b[a-zA-ZÀ-ÿ]{3,}\b',  # only words longer than 3 letters and no numbers to prevent temporal when modeling
    max_df=0.95,
    min_df=20
)

# Fit and transform
X = vectorizer.fit_transform(df_cleaned['text'])

# Get words and counts
words = vectorizer.get_feature_names_out()
word_counts = np.array(X.sum(axis=0)).flatten()

# Combine and sort
freq = [(word, int(word_counts[i])) for i, word in enumerate(words)]
freq_sorted = sorted(freq, key=lambda x: x[1], reverse=True)

# Take top words
top_words = freq_sorted[:20]
words = [w[0] for w in top_words]
counts = [w[1] for w in top_words]

# Plot
plt.figure(figsize=(10,8))
plt.barh(words, counts)
plt.xlabel("Frequency")
plt.title("Top 20 Most Frequent Words in Corpus with Extra Stopwords Removed")
plt.gca().invert_yaxis() 
plt.show()

# %% [markdown]
# #### Lemmatization

# %%
# Initialize CountVectorizer
vectorizer = CountVectorizer(
    stop_words=all_stopwords,
    token_pattern=r'\b[a-zA-ZÀ-ÿ]{3,}\b',  # only words longer than 3 letters and no numbers to prevent temporal when modeling
    max_df=0.95,
    min_df=20
)

# Fit and transform
X = vectorizer.fit_transform(df_cleaned['text_lemma']) # use lemmatized text

# Get words and counts
words = vectorizer.get_feature_names_out()
word_counts = np.array(X.sum(axis=0)).flatten()

# Combine and sort
freq = [(word, int(word_counts[i])) for i, word in enumerate(words)]
freq_sorted = sorted(freq, key=lambda x: x[1], reverse=True)

# Take top words
top_words = freq_sorted[:20]
words = [w[0] for w in top_words]
counts = [w[1] for w in top_words]

# Plot
plt.figure(figsize=(10,8))
plt.barh(words, counts)
plt.xlabel("Frequency")
plt.title("Top 20 Most Frequent Words in Corpus with Extra Stopwords Removed + Lemmatization")
plt.gca().invert_yaxis() 
plt.show()

# %%
# Retrieve full vocabulary
vocab = vectorizer.get_feature_names_out()

# Top parties
top_parties = df_cleaned['party_clean'].value_counts().head(5).index

for party in top_parties:
    
    idx = (df_cleaned['party_clean'] == party).values
    
    mean_counts = X[idx].mean(axis=0)
    
    sorted_indices = np.argsort(mean_counts.A1)[::-1][:15]
    
    print("\nParty:", party)
    print([vocab[i] for i in sorted_indices])
# Out:
# Party: Other
# ['politique', 'gauche', 'social', 'français', 'national', 'france', 'emploi', 'droite', 'nouveau', 'parti', 'pouvoir', 'vie', 'voter', 'communiste', 'majorité']
#
# Party: Liste d'entente populaire et nationale
# ['national', 'front', 'vote', 'français', 'député', 'avenir', 'force', 'rpr', 'udf', 'voter', 'france', 'vif', 'confiance', 'populaire', 'conviction']
#
# Party: Entente des écologistes
# ['écologie', 'entente', 'écologiste', 'vie', 'politique', 'environnement', 'ecologie', 'nouveau', 'verts', 'humain', 'assemblée', 'ecologiste', 'homme', 'génération', 'generation']
#
# Party: Union pour une nouvelle majorité
# ['liberté', 'france', 'majorité', 'socialiste', 'politique', 'union', 'national', 'français', 'social', 'nouvelle', 'député', 'communiste', 'pouvoir', 'société', 'parti']
#
# Party: Union du rassemblement et du centre
# ['union', 'france', 'centre', 'national', 'rassemblement', 'socialiste', 'français', 'député', 'pouvoir', 'général', 'politique', 'homme', 'social', 'emploi', 'parti']

# %% [markdown]
# ### TfidfVectorizer

# %%
# get top parties
top_parties = df_cleaned['party_clean'].value_counts().head().index
top_parties
# Out:
# Index(['Other', 'Liste d'entente populaire et nationale',
#        'Entente des écologistes', 'Union pour une nouvelle majorité',
#        'Union du rassemblement et du centre'],
#       dtype='str', name='party_clean')

# %%
# only top 6 parties
df_top = df_cleaned[df_cleaned['party_clean'].isin(top_parties)]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Initialize TfidfVectorizer
tfidf = TfidfVectorizer(
    stop_words=all_stopwords,
    token_pattern=r'\b[a-zA-ZÀ-ÿ]{3,}\b',  # removes numbers & short tokens
    max_df=0.9,
    min_df=10
)

# Fit and transform the text data
X_tfidf = tfidf.fit_transform(df_top['text_lemma'])
terms = tfidf.get_feature_names_out()

# Get feature names and their corresponding TF-IDF scores
tfidf_scores = np.array(X_tfidf.sum(axis=0)).flatten()
tfidf_freq = [(terms[i], round(float(tfidf_scores[i]), 2)) for i in range(len(terms))]
tfidf_freq_sorted = sorted(tfidf_freq, key=lambda x: x[1], reverse=True)

# Top 20 TF-IDF terms
tfidf_freq_sorted[:20]
# Out:
# [('national', 196.98),
#  ('front', 140.01),
#  ('français', 116.98),
#  ('vote', 111.35),
#  ('politique', 104.14),
#  ('député', 93.7),
#  ('france', 92.73),
#  ('écologie', 90.15),
#  ('voter', 83.63),
#  ('rpr', 82.71),
#  ('udf', 82.0),
#  ('avenir', 79.93),
#  ('force', 79.82),
#  ('vie', 76.19),
#  ('entente', 74.56),
#  ('union', 72.54),
#  ('écologiste', 71.8),
#  ('social', 71.37),
#  ('nouveau', 68.73),
#  ('gauche', 66.78)]

# %%
# Analyze top TF-IDF terms for each party
for party in top_parties:
    idx = (df_top['party_clean'] == party).values
    mean_tfidf = X_tfidf[idx].mean(axis=0)
    sorted_indices = np.argsort(mean_tfidf.A1)[::-1][:15]
    print("\nParty:", party)
    print([terms[i] for i in sorted_indices])
# Out:
# Party: Other
# ['gauche', 'politique', 'droite', 'communiste', 'majorité', 'parti', 'français', 'social', 'france', 'pouvoir', 'vie', 'national', 'homme', 'emploi', 'changement']
#
# Party: Liste d'entente populaire et nationale
# ['national', 'front', 'vote', 'rpr', 'udf', 'français', 'vif', 'avenir', 'député', 'liste', 'conviction', 'suppression', 'force', 'ici', 'populaire']
#
# Party: Entente des écologistes
# ['écologie', 'entente', 'écologiste', 'environnement', 'ecologie', 'ecologiste', 'verts', 'humain', 'vie', 'generation', 'ecologistes', 'génération', 'chance', 'politique', 'vert']
#
# Party: Union pour une nouvelle majorité
# ['majorité', 'nouvelle', 'liberté', 'communiste', 'socialiste', 'union', 'france', 'politique', 'parti', 'changement', 'société', 'non', 'français', 'député', 'pouvoir']
#
# Party: Union du rassemblement et du centre
# ['centre', 'union', 'rassemblement', 'france', 'socialiste', 'ouverture', 'général', 'pouvoir', 'député', 'national', 'français', 'président', 'parti', 'formation', 'homme']
